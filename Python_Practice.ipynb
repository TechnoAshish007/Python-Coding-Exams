# %% [markdown]
# ## Python Practice

# %% [markdown]
# ### Exercise::1 :: Create a dictionary and take input from the user and return the meaning of the word from the dictionary?

# %%
myDict = {"Armour":"Guard", "Tea":"Drink", "Food":"Eat", "Fat":"Bulky", "Dark":"Black"}

# %%
x = input("Enter the name:")
print(myDict[x])
# Out:
# Enter the name:Tea
# Drink

# %% [markdown]
# ### Exercise::2 :: Design a calculator which will solve all the problems correctly except the following ones( 45*3=555, 56+9=77, 56/6=4)

# %%
print("Select operation from the operators below")
print("+ for Add")
print("- for Subtract")
print("* for Multiply")
print("/ for Divide")

user_choice = input("Enter choice(+/-/*//): ")

if user_choice in ('+', '-', '*', '/'):
    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))
    
    if num1==45 and num2==3 and user_choice=="*":
        print("555")
    elif num1==56 and num2==9 and user_choice=="+":
        print("77")
    elif num1==56 and num2==6 and user_choice=="/":
        print("4")
    elif user_choice=="+":
        print(num1+num2)
    elif user_choice=="-":
        print(num1-num2)
    elif user_choice=="*":
        print(num1*num2)
    elif user_choice=="/":
        print(num1/num2)
else:
    print("Invalid Input")
# Out:
# Select operation from the operators below
# + for Add
# - for Subtract
# * for Multiply
# / for Divide
# Enter choice(+/-/*//): /
# Enter first number: 77
# Enter second number: 11
# 7.0

# %% [markdown]
# ### Exercise::3 :: Number guessing system(Print number of guesses and hints(given that secret_num =17 )
# #### Task 1 = limit the number of guesses to 9
# #### Task 2 = print the number of guesses left
# #### Task 3 = print number of guesses to finish
# #### Task 4 = print game over

# %%
secret_num = 17
print("Welcome to secret number guessing game")
user_input_num = int(input("Please guess a number between 1 and 100: "))
guess_count = 1
game_over = False

while not game_over:
    if (secret_num == user_input_num):
        print(f"Congratulations! You guessed it right in {guess_count} guess")
        game_over = True
        print("Game Over")
        
    elif (secret_num > user_input_num):
        print(f"Oops! your guess is too low")
        guess_count += 1
        print(f"You have {9 - (guess_count)} guesses left")
        user_input_num = int(input("Please guess again: "))
        
    else:
        print(f"Oops! your guess is too high")
        guess_count += 1
        print(f"You have {9 - (guess_count)} guesses left")
        user_input_num = int(input("Please guess again: "))
# Out:
# Welcome to secret number guessing game
# Please guess a number between 1 and 100: 17
# Congratulations! You guessed it right in 1 guess
# Game Over

# %% [markdown]
# ### Exercise::4 :: Pattern Printing

# %%
print("This is pattern printing exercise")
num_rows = int(input("How many rows you want to print in pattern: "))
print("Please select pattern type: 0 for increasing rows or 1 for decreasing rows")
pattern_type = input("Enter pattern type 0 or 1: ")
if pattern_type == "1":
    for i in range(0, num_rows+1):
        print("*"*i)

elif pattern_type=="0":
    for i in range(num_rows,0,-1):
        print("*"*i)
# Out:
# This is pattern printing exercise
# How many rows you want to print in pattern: 17
# Please select pattern type: 0 for increasing rows or 1 for decreasing rows
# Enter pattern type 0 or 1: 0
# *****************
# ****************
# ***************
# **************
# *************
# ************
# ***********
# **********
# *********
# ********
# *******
# ******
# *****
# ****
# ***
# **
# *

# %% [markdown]
# ### Exercise::5 :: Health Management System for clients (3 clients, 6 files)

# %%
# Health Management System
# 3 clients - Maive, Otis and Ola
# Total 6 files
# write a function that when executed takes as input client name
# One more function to retrieve exercise or food for any client

import datetime
def gettime():
    return datetime.datetime.now()
def take(k):
    if k==1:
        c=int(input("Enter 1 for exercise and 2 for food"))
        if(c==1):
            value=input("type here\n")
            with open("maive-exercise.txt","a") as op:
                op.write(str([str(gettime())])+": "+value+"\n")
            print("successfully written")
        elif(c==2):
            value = input("type here\n")
            with open("maive-food.txt", "a") as op:
                op.write(str([str(gettime())]) + ": " + value + "\n")
            print("successfully written")
    elif(k==2):
        c = int(input("Enter 1 for exercise and 2 for food"))
        if (c == 1):
            value = input("type here\n")
            with open("otis-exercise.txt", "a") as op:
                op.write(str([str(gettime())]) + ": " + value + "\n")
            print("successfully written")
        elif (c == 2):
            value = input("type here\n")
            with open("otis-food.txt", "a") as op:
                op.write(str([str(gettime())]) + ": " + value + "\n")
            print("successfully written")
    elif(k==3):
        c = int(input("Enter 1 for exercise and 2 for food"))
        if (c == 1):
            value = input("type here\n")
            with open("ola-exercise.txt", "a") as op:
                op.write(str([str(gettime())]) + ": " + value + "\n")
            print("successfully written")
        elif (c == 2):
            value = input("type here\n")
            with open("ola-food.txt", "a") as op:
                op.write(str([str(gettime())]) + ": " + value + "\n")
            print("successfully written")
    else:
        print("plz enter valid input (1(harry),2(rohan),3(hammad)")
def retrieve(k):
    if k==1:
        c=int(input("Enter 1 for exercise and 2 for food"))
        if(c==1):
            with open("maive-exercise.txt") as op:
                for i in op:
                    print(i,end="")
        elif(c==2):
            with open("maive-food.txt") as op:
                for i in op:
                    print(i, end="")
    elif(k==2):
        c = int(input("Enter 1 for exercise and 2 for food"))
        if (c == 1):
            with open("otis-exercise.txt") as op:
                for i in op:
                    print(i, end="")
        elif (c == 2):
            with open("otis-food.txt") as op:
                for i in op:
                    print(i, end="")
    elif(k==3):
        c = int(input("Enter 1 for exercise and 2 for food"))
        if (c == 1):
            with open("ola-exercise.txt") as op:
                for i in op:
                    print(i, end="")
        elif (c == 2):
            with open("ola-food.txt") as op:
                for i in op:
                    print(i, end="")
    else:
        print("plz enter valid input (maive,otis,ola)")
print("Health Management System: ")

a=int(input("Enter 1 for log the value and 2 to retrieve the value: "))

if a==1:
    b = int(input("Enter 1 for maive 2 for otis 3 for ola "))
    take(b)
else:
    b = int(input("Press 1 for maive 2 for otis 3 for ola "))
    retrieve(b)
# Out:
# Health Management System:
# Enter 1 for log the value and 2 to retrieve the value: 2
# Press 1 for maive 2 for otis 3 for ola 3
# Enter 1 for exercise and 2 for food3

# %% [markdown]
# ### Excercise::6 :: Snake Water Gun Game

# %%
# Snake water gun

import random
lst = ['s','w','g']

chance = 10
no_of_chance = 0
computer_point = 0
human_point = 0

print(" \t \t \t \t Snake,Water,Gun Game\n \n")
print("s for snake \nw for water \ng for gun \n")

# making the game in while
while no_of_chance < chance:
    _input = input('Snake,Water,Gun:')
    _random = random.choice(lst)

    if _input == _random:
        print("Tie Both 0 point to each \n ")

    # if user enter s
    elif _input == "s" and _random == "g":
        computer_point = computer_point + 1
        print(f"your guess {_input} and computer guess is {_random} \n")
        print("computer wins 1 point \n")
        print(f"computer_point is {computer_point} and your point is {human_point} \n ")

    elif _input == "s" and _random == "w":
        human_point = human_point + 1
        print(f"your guess {_input} and computer guess is {_random} \n")
        print("Human wins 1 point \n")
        print(f"computer_point is {computer_point} and your point is {human_point} \n")

    # if user enter w
    elif _input == "w" and _random == "s":
        computer_point = computer_point + 1
        print(f"your guess {_input} and computer guess is {_random} \n")
        print("computer wins 1 point \n")
        print(f"computer_point is {computer_point} and your point is {human_point} \n ")

    elif _input == "w" and _random == "g":
        human_point = human_point + 1
        print(f"your guess {_input} and computer guess is {_random} \n")
        print("Human wins 1 point \n")
        print(f"computer_point is {computer_point} and your point is {human_point} \n")

    # if user enter g

    elif _input == "g" and _random == "s":
        human_point = human_point + 1
        print(f"your guess {_input} and computer guess is {_random} \n")
        print("Human wins 1 point \n")
        print(f"computer_point is {computer_point} and your point is {human_point} \n")


    elif _input == "g" and _random == "w":
        computer_point = computer_point + 1
        print(f"your guess {_input} and computer guess is {_random} \n")
        print("computer wins 1 point \n")
        print(f"computer_point is {computer_point} and your point is {human_point} \n ")

    else:
        print("you have input wrong \n")

    no_of_chance = no_of_chance + 1
    print(f"{chance - no_of_chance} is left out of {chance} \n")

print("Game over")

if computer_point==human_point:
    print("Tie")

elif computer_point > human_point:
    print("Computer wins and you loose")

else:
    print("you win and computer loose")

print(f"your point is {human_point} and computer point is {computer_point}")

#
# Snake Water Gun Game in Python
# The snake drinks the water, the gun shoots the snake, and gun has no effect on water.
# Out:
#  	 	 	 	 Snake,Water,Gun Game
#
#
# s for snake
# w for water
# g for gun
#
# Snake,Water,Gun:w
# Tie Both 0 point to each
#
# 9 is left out of 10
#
# Snake,Water,Gun:w
# your guess w and computer guess is g
#
# Human wins 1 point
#
# computer_point is 0 and your point is 1
#
# 8 is left out of 10
#
# Snake,Water,Gun:w
# Tie Both 0 point to each
#
# 7 is left out of 10
#
# Snake,Water,Gun:g
# your guess g and computer guess is s
#
# Human wins 1 point
#
# computer_point is 0 and your point is 2
#
# 6 is left out of 10
#
# Snake,Water,Gun:g
# Tie Both 0 point to each
#
# 5 is left out of 10
#
# Snake,Water,Gun:g
# Tie Both 0 point to each
#
# 4 is left out of 10
#
# Snake,Water,Gun:g
# your guess g and computer guess is s
#
# Human wins 1 point
#
# computer_point is 0 and your point is 3
#
# 3 is left out of 10
#
# Snake,Water,Gun:g
# your guess g and computer guess is w
#
# computer wins 1 point
#
# computer_point is 1 and your point is 3
#
# 2 is left out of 10
#
# ...

# %% [markdown]
# ### Exercise::7 :: Healthy Programmer (Water, Eyes, Physical)

# %%
#Healthy Programmer
# 9am - 5pm
# Water - water.mp3 (3.5 litres) - Drank - log - Every 40 min
# Eyes - eyes.mp3 - every 30 min - EyDone - log - Every 30 min
# Physical activity - physical.mp3 every - 45 min - ExDone - log
# Rules
# Pygame module to play audio

from pygame import mixer
from datetime import datetime
from time import time

def musiconloop(file, stopper):
    mixer.init()
    mixer.music.load(file)
    mixer.music.play()
    while True:
        input_of_user = input()
        if input_of_user == stopper:
            mixer.music.stop()
            break

def log_now(msg):
    with open("mylogs.txt", "a") as f:
        f.write(f"{msg} {datetime.now()}\n")

if __name__ == '__main__':
    # musiconloop("water.mp3", "stop")
    init_water = time()
    init_eyes = time()
    init_exercise = time()
    watersecs = 40*60
    exsecs = 30*60
    eyessecs = 45*60

    while True:
        if time() - init_water > watersecs:
            print("Water Drinking time. Enter 'drank' to stop the alarm.")
            musiconloop('water.mp3', 'drank')
            init_water = time()
            log_now("Drank Water at")

        if time() - init_eyes >eyessecs:
            print("Eye exercise time. Enter 'doneeyes' to stop the alarm.")
            musiconloop('eyes.mp3', 'doneeyes')
            init_eyes = time()
            log_now("Eyes Relaxed at")

        if time() - init_exercise > exsecs:
            print("Physical Activity Time. Enter 'donephy' to stop the alarm.")
            musiconloop('physical.mp3', 'donephy')
            init_exercise = time()
            log_now("Physical Activity done at")
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-91e5330cda8a> in <module>
#      47             log_now("Eyes Relaxed at")
#      48
# ---> 49         if time() - init_exercise > exsecs:
#      50             print("Physical Activity Time. Enter 'donephy' to stop the alarm.")
#      51             musiconloop('physical.mp3', 'donephy')
#
# KeyboardInterrupt:
